# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !git clone https://github.com/realcrane/iPLAN-Interactive-and-Procedural-Layout-Planning
# Out:
# Cloning into 'iPLAN-Interactive-and-Procedural-Layout-Planning'...
# remote: Enumerating objects: 301, done.
# remote: Counting objects: 100% (210/210), done.
# remote: Compressing objects: 100% (156/156), done.
# remote: Total 301 (delta 96), reused 106 (delta 46), pack-reused 91
# Receiving objects: 100% (301/301), 12.98 MiB | 19.72 MiB/s, done.
# Resolving deltas: 100% (117/117), done.

# %%
import torch

# %%
import os
print("Directory di lavoro corrente:", os.getcwd())
roomType_directory = '/content/iPLAN-Interactive-and-Procedural-Layout-Planning/room_partition'
os.chdir(roomType_directory)
print("Nuova directory di lavoro:", os.getcwd())
# Out:
# Directory di lavoro corrente: /content
# Nuova directory di lavoro: /content/iPLAN-Interactive-and-Procedural-Layout-Planning/room_partition

# %%
path_model_roomType = "/content/drive/MyDrive/Colab_Notebooks/Deep_Learning/Progetto/Model/room_partition/G_net_210.pth"
pickle_path = "/content/drive/MyDrive/Colab_Notebooks/Deep_Learning/Progetto/Model/room_partition/renderer.pkl"

# %%
from config_partition import PartitionConfig
opt = PartitionConfig()
opt.load_netG_path = path_model_roomType

# %%
from pathlib import Path
dir = Path("/content/drive/MyDrive/Colab_Notebooks/Deep_Learning/Progetto/Model/room_partition/log/")
try:
    dir.mkdir()
except FileExistsError:
    print(f"La cartella {dir} esiste già")
# Out:
# La cartella /content/drive/MyDrive/Colab_Notebooks/Deep_Learning/Progetto/Model/room_partition/log esiste già

# %%
opt.save_log_root = str(dir)
log_file = open(f"{opt.save_log_root}/log.txt", 'w')

# %%
def set_seeds(seed=0):
    torch.manual_seed(seed)  # sets the seed for generating random numbers.
    torch.cuda.manual_seed(seed)  # Sets the seed for generating random numbers for the current GPU.
    torch.cuda.manual_seed_all(seed)  # Sets the seed for generating random numbers on all GPUs
    torch.backends.cudnn.deterministic = True

set_seeds(seed=19920409)

# %%
import os

os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# %%
import models
fp_rnn = models.FloorPlanRNN(opt, log_file)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-15-f1d0e5c47670> in <cell line: 2>()
#       1 import models
# ----> 2 fp_rnn = models.FloorPlanRNN(opt, log_file)
#
# /content/iPLAN-Interactive-and-Procedural-Layout-Planning/room_partition/models/floorplan_rnn.py in __init__(self, opt, log_file)
#      22
#      23         # configure model
# ---> 24         self.netG = BoundingBoxNet().to(self.device)
#      25         self.netR = RendererNet().to(self.device)
#      26         self.netD = NLayerDiscriminator().to(self.device)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in to(self, *args, **kwargs)
#    1158             return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#    1159
# -> 1160         return self._apply(convert)
#    1161
#    1162     def register_full_backward_pre_hook(
#
# ...
